# %% [markdown]
# <a href="https://colab.research.google.com/github/SuniL-0007/NLP-Lab/blob/main/NLP_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/Mammo.csv")

# %%
df
# Out:
#                                               Features  Birads
# 0    Soft tissue mass lesion (23 x 20 mm) with spic...       4
# 1    Parenchyma is predominantly FATTY.No distinctl...       1
# 2    Parenchyma is predominantly GLANDULAR. No dist...       1
# 3    Parenchyma is predominantly GLANDULAR. No dist...       2
# 4    Parenchyma is GLANDULAR and FATTY. Small subce...       2
# ..                                                 ...     ...
# 102  Parenchyma is predominantly FATTY. Few tiny be...       2
# 103  Parenchyma is predominantly FATTY. Few tiny be...       2
# 104  Parenchyma is predominantly glandular. Fibroad...       2
# 105  Parenchyma is predominantly GLANDULAR. A well ...       5
# 106  Parenchyma is predominantly GLANDULAR. A well ...       1
#
# [107 rows x 2 columns]

# %%
df.shape
# Out:
# (107, 2)

# %%
import nltk

# %%
from textblob import TextBlob

text = "I love Python programming, it's awesome!"
blob = TextBlob(text)

# Sentiment analysis
sentiment = blob.sentiment
print(f"Polarity: {sentiment.polarity}, Subjectivity: {sentiment.subjectivity}")
# Out:
# Polarity: 0.75, Subjectivity: 0.8
